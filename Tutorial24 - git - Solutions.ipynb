# %% [markdown]
# For this Tutorial, you do not need to turn in a `jupyter` notebook. To submit to D2L, you will simply post the URL to your github repository.

# %% [markdown]
# # think+code: set up `git` for the first time
#
# These are commands that you need to run *once* on a new computer, to set up your basic `git` configuration. If you want to use `git` on your laptop, run these once and then you'll never have to again. Run them ***in the UNIX prompt*** (with your own identity, of course.)
#
# ```
# git config --global user.name "Katherine Johnson"
# git config --global user.email sentusto@themoon.com
# ```

# %% [raw]
# (you should have run these commands in the UNIX prompt)

# %% [markdown]
# # think+web: set up `github`
#
# Go online to `https://education.github.com` to create a github account for yourself, and to request a student discount using your CU Boulder email. Anyone can get a free account on `github` for public repositories. With the student discount you'll also get free private repositories, meaning you can use `github` as private cloud storage for your code. If you find you don't like `github`, you can always delete these accounts later.

# %% [raw]
# (now you have a github account that you can use for future coding projects!)

# %% [markdown]
# # think+code: create a new `git` repository
#
# + On `github`, use the "+" at the upper right of the screen to make a "New Repository".
#
#     + Set the Repository Name to "stars".
#     + Click yes to "Initialize this repository with a README".
#     + Click "Create repository".
#
# + You have now created a new `git` repository, stored on your `github` account. Click the green "Clone or download" button in this repository. Copy the link that it generates to the clipboard.
#
# + Come back to a UNIX prompt. Navigate to a directory where you want to store your `starplots` repository. From there, type "```git clone {that-link-that-you-just-copied}```". This will download a copy of the repository to your local directory, but keeped it linked to the online one, so you can post updates to there.

# %% [raw]
# You can see my version of this github repository at https://github.com/zkbt/stars

# %% [markdown]
# # think+code: modify your `github` repo
#
# + Copy the file `/home/zabe0091/sharedcode/radec.py` into your new local `starplots` directory.
#
# + From inside your `starplots` directory, run the following commands, and pay attention to what they do:
#
#     + ```python radec.py```
#         + (this runs the Python module, to see what it does)
#     + ```git log```
#         + (the shows your history of commits)
#     + ```git status```
#         + (this shows what has and hasn't been committed)
#     + ```git add radec.py```
#         + (this adds `radec.py` to the staging area)
#     + ```git status```
#     + ```git commit -m "Add a new star plotting function."```
#         + (this commits the change to the local repository)
#     + ```git status```
#     + ```git log```
#     + ```git push```
#         + (this uploads committed changes to the server)
#
# + Go back to your `github` repository page, and check to see that you can see your new `radec.py` file there. While on that page, click the `README.md` file and use the little pencil symbol to edit it. Commit your changes to `README.md`.
#
# + Back in the UNIX prompt (in the `starplots` directory) run the following:
#
#     + ```git pull```
#         + (this downloads any changes that were made to the repo)
#     + ```git log```

# %%
# let's store the results of radec.py inside the notebook
# %matplotlib inline

# "%run radec.py" from within ipython is the same as "python radec.py" from the UNIX terminal
# %run radec

# %% [raw]
# This function makes a plot of the R.A. and Declination of a bunch of stars from the Hipparcos catalog.

# %% [markdown]
# # think+web: (try to) install `corner.py`
#
# In your web browser, navigate to `https://github.com/dfm/corner.py`. Read the documentation, and attempt to install it on `scorpius` using `pip`. (It won't work, because you don't have write permissions to the inner guts of `scorpius`, but on your own computers, it will work.)
#
# I installed a (slightly hacked) version that gives you all access to the `corner` module on `scorpius`, so we can pretend that your installation worked.

# %% [markdown]
# # think+code: Hertzsprung-Russell (and more!)
# Now, copy the `/home/zabe0091/sharedcode/HR.py` file into your `starplots` directory. From there, run
#
# + `python HR.py`
#
# to see what it does.

# %%
# %run HR

# %% [raw]
# The `corner` module called by `HR.py` allows us to easily plot lots of different parallel columns against each other. One panel in here plots the absolute V magnitude (which represents the intrinsic luminosity of a star) vs. the V-I color (which represents the temperature of the star). So, that top left corner is basically a real Hertzsprung-Russell diagram. It looks upside down because lower magnitudes correspond to higher luminosities, but you can clearly see the main-sequence, the giant branch (stars that are red, with high V-I color, and bright, with small absolute V magnitudes), and if you look closely, even a few white dwarfs (low V-I color, high absolute magnitude).

# %% [markdown]
# # think+pair+code: push to `github`
#
# Working with your neighbor(s), figure out how to commit the changes you've made to the `starplots` directory to the local git repository, and then push the updates to your remote `github` repository. Go online, to see if the changes have been made.

# %% [raw]
# You can see my version of this github repository at https://github.com/zkbt/stars

# %% [markdown]
# ***When finished, simply post the link to your github repository in the “Tutorial 24” folder. Please fill out the 1-minute Reflect+Respond survey on D2L.***
